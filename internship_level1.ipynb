# %% [markdown]
# LEVEL 1

# %% [markdown]
# TASK 1

# %% [markdown]
# Task: Data Exploration and Preprocessing

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns;sns.set(color_codes=True)
# %matplotlib inline

# %%
#READING THE GIVEN CSV FILE i.e., DATASET1.CSV
data=pd.read_csv("C:/Users/Lezan/Downloads/dataset1.csv")

# %%
#DISPLAYING THE FIRST FIVE ROWS OF THE DATASET
data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
#PRINTING THE SUMMARY OF THE GIVEN DATASET
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [markdown]
# Explore the dataset and identify the number of rows and columns.

# %%
#FINDING OUT NUMBER OF ROWS AND COLUMNS
data.shape
# Out:
# (9551, 21)

# %%
#FINDING NUMBER OF ROWS AND COLUMNS
rows=len(data.axes[0])
cols=len(data.axes[1])
print("Number of rows are",rows)
print("Number of columns are",cols)
# Out:
# Number of rows are 9551
# Number of columns are 21

# %% [markdown]
# Check for missing values in each column and handle them accordingly.

# %%
#FINDING THE NUMBER MISSING VALUES IN EACH COLUMN OF THE DATASET.
missing_val_c=data.isnull().sum()
missing_val_c[1:21]
# Out:
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
#SINCE THE DATASET GIVEN IS VERY HUGE AND THE NUMBER OF ROWS HAVING MISSING VALUES IS VERY LESS WE CAN DROP THE ROWS WITH MISSING VALUES
data1=data.dropna()
data1
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
#CHECK FOR DUPLICATES.
dup=data1.duplicated().sum()
print('number of duplicate rows are',dup)
# Out:
# number of duplicate rows are 0

# %%
#NUMBER OF ROWS AND COLUMNS AFTER THE REMOVAL OF MISSING VALUES.
rows1=len(data1.axes[0])
cols1=len(data1.axes[1])
print("Number of rows are",rows1)
print("Number of columns are",cols1)
# Out:
# Number of rows are 9542
# Number of columns are 21

# %%
#FINDING THE NUMBER MISSING VALUES IN EACH COLUMN OF THE DATASET.
missing_val_c=data1.isnull().sum()
missing_val_c[1:21]
# Out:
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# Perform data type conversion if necessary.

# %%
#TO PERFORM TYPE CONVERSIONS IF NECESSARY.
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9542 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9542 non-null   int64
#  1   Restaurant Name       9542 non-null   object
#  2   Country Code          9542 non-null   int64
#  3   City                  9542 non-null   object
#  4   Address               9542 non-null   object
#  5   Locality              9542 non-null   object
#  6   Locality Verbose      9542 non-null   object
#  7   Longitude             9542 non-null   float64
#  8   Latitude              9542 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9542 non-null   int64
#  11  Currency              9542 non-null   object
#  12  Has Table booking     9542 non-null   object
#  13  Has Online delivery   9542 non-null   object
#  14  Is delivering now     9542 non-null   object
# ...

# %% [markdown]
# No need to do data type conversion.

# %% [markdown]
# Analyze the distribution of the target variable ("Aggregate rating") and identify any class imbalances.

# %%
#COUNTING THE RATING
g=data1['Aggregate rating'].value_counts(sort=False)
g
# Out:
# 4.8      25
# 4.5      95
# 4.4     143
# 4.9      61
# 4.0     266
# 4.2     221
# 4.3     174
# 3.6     458
# 4.7      41
# 3.0     468
# 3.8     399
# 3.7     427
# 3.2     522
# 3.1     519
# 0.0    2148
# 4.1     274
# 3.3     483
# 4.6      78
# 3.9     332
# 3.4     495
# 3.5     480
# 2.2      27
# 2.9     381
# 2.4      87
# 2.6     191
# 2.8     315
# 2.1      15
# 2.7     250
# 2.5     110
# 1.8       1
# 2.0       7
# 2.3      47
# 1.9       2
# Name: Aggregate rating, dtype: int64

# %%
#TARGET VARIABLE "AGGREGATE RATING"
target= "Aggregate rating"
print(data1[target].describe())
# Out:
# count    9542.000000
# mean        2.665238
# std         1.516588
# min         0.000000
# 25%         2.500000
# 50%         3.200000
# 75%         3.700000
# max         4.900000
# Name: Aggregate rating, dtype: float64

# %%
#BOXPLOT
plt.figure(figsize=(7,5))
sns.boxplot(x=data1[target])
plt.title('BOXPLOT')
plt.xlabel('aggregate rating')
plt.show()

# %%
#HISTOGRAM
plt.figure(figsize=(7,5))
sns.histplot(data1[target],bins=30,color='red',kde=True)
plt.title('HISTOGRAM')
plt.xlabel('aggregate rating')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# TASK 2

# %% [markdown]
# Task: Descriptive Analysis

# %% [markdown]
# Calculate basic statistical measures (mean,median, standard deviation, etc.) for numerical columns.

# %%
#FINDING THE NUMERICAL COLUMNS
data1.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.542000e+03   9542.000000  9542.000000  9542.000000
# mean    9.043301e+06     18.179208    64.274997    25.848532
# std     8.791967e+06     56.451600    41.197602    11.010094
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019312e+05      1.000000    77.081565    28.478658
# 50%     6.002726e+06      1.000000    77.192031    28.570444
# 75%     1.835260e+07      1.000000    77.282043    28.642711
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9542.000000  9542.000000       9542.000000   9542.000000
# mean            1200.326137     1.804968          2.665238    156.772060
# std            16128.743876     0.905563          1.516588    430.203324
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
#CALCULTING THE BASIC STATISTICAL MEASURES FOR THE NUMERICAL COLUMNS
data1[["Average Cost for two","Price range","Aggregate rating","Votes"]].describe()
# Out:
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9542.000000  9542.000000       9542.000000   9542.000000
# mean            1200.326137     1.804968          2.665238    156.772060
# std            16128.743876     0.905563          1.516588    430.203324
# min                0.000000     1.000000          0.000000      0.000000
# 25%              250.000000     1.000000          2.500000      5.000000
# 50%              400.000000     2.000000          3.200000     31.000000
# 75%              700.000000     2.000000          3.700000    130.000000
# max           800000.000000     4.000000          4.900000  10934.000000

# %% [markdown]
# Explore the distribution of categorical variables like "Country Code","City" and "Cuisines".

# %%
#EXPLORE THE DITRIBUTION OF COUNTRY CODE
plt.figure(figsize=(7,5))
sns.countplot(x='Country Code',data=data1)
plt.title("Distribution of restaurants according to country code")
plt.xlabel('country code')
plt.ylabel('No. of restaurants')
plt.show()

# %% [markdown]
# Highest number of restaurants are there in country code 1 and the second highest in country code 216

# %%
#EXPLORE THE DITRIBUTION OF CITIIES
plt.figure(figsize=(10,7))
sns.countplot(x='City',data=data1,order=data1['City'].value_counts().head(40).index)
plt.xticks(rotation=75)
plt.title("Distribution of restaurants according to cities")
plt.xlabel('city')
plt.ylabel('No. of restaurants')
plt.show()

# %% [markdown]
# Highest number of restaurants are there in New Delhi and the second highest in Gurgoan

# %%
#EXPLORE THE DITRIBUTION OF cuisines
plt.figure(figsize=(15,5))
sns.countplot(x='Cuisines',data=data1,order=data1['Cuisines'].value_counts().head(40).index)
plt.xticks(rotation=90)
plt.title("Distribution of restaurants according to cuisines")
plt.xlabel('cuisine')
plt.ylabel('No. of restaurants')
plt.show()

# %% [markdown]
# Top cuisine in many restaurants is north indian and chinese

# %% [markdown]
# Identify the top cuisines and cities with the highest number of restaurants.

# %%
#TOP 15 CUISINES WITH HIGHEST NUMBER OF RESTAURANTS
topcuisine=data1['Cuisines'].value_counts().head(15)
print(" Top 15 cuisines with the highest number of restaurants is:")
topcuisine
# Out:
#  Top 15 cuisines with the highest number of restaurants is:
# North Indian                      936
# North Indian, Chinese             511
# Chinese                           354
# Fast Food                         354
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            218
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Pizza, Fast Food                  131
# Chinese, Fast Food                118
# Mithai, Street Food               116
# South Indian                      112
# Bakery, Fast Food                 108
# Name: Cuisines, dtype: int64

# %%
#TOP 15 CITIIES WITH HIGHEST NUMBER OF RESTAURANTS
topcities=data1['City'].value_counts().head(15)
print(" Top 15 cities with the highest number of restaurants is:")
topcities
# Out:
#  Top 15 cities with the highest number of restaurants is:
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Ahmedabad         21
# Guwahati          21
# Amritsar          21
# Bhubaneshwar      21
# Lucknow           21
# Dubai             20
# Kochi             20
# Indore            20
# Jaipur            20
# Kanpur            20
# Name: City, dtype: int64

# %% [markdown]
# Task 3

# %% [markdown]
# Task: Geospatial Analysis

# %%
#INSTALLING GEOPANDAS 
pip install geopandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#IMPORT LIBRARIES
import geopandas as gpd
from geopandas import GeoDataFrame
from shapely.geometry import Point

# %% [markdown]
# Visualize the locations of restaurants on a map using latitude and longitude information

# %%
#VISUASLIZING THE LOCATIONS OF RESTAURANTS ON A MAP USING LATITUDE AND LONGITUDE INFORMATION.
gll=gpd.GeoDataFrame(data1,geometry=gpd.points_from_xy(data1.Longitude,data1.Latitude))
map=gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
gll.plot(ax=map.plot("continent",figsize=(20,20)),marker='*',color='red')
plt.show()
# Out:
# C:\Users\Lezan\AppData\Local\Temp\ipykernel_14308\1634529246.py:2: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   map=gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %% [markdown]
# Analyze the distribution of restaurants across different cities or countries.

# %%
#EXPLORE THE DITRIBUTION OF RESTAURANTS ACROSS DIFFERENT CITIIES.
plt.figure(figsize=(10,7))
sns.countplot(x='City',data=data1,order=data1['City'].value_counts().head(25).index)
plt.xticks(rotation=75)
plt.title("Distribution of restaurants according to cities")
plt.xlabel('city')
plt.ylabel('No. of restaurants')
plt.show()

# %% [markdown]
# Determine if there is any correlation between the restaurant's location and its rating.

# %%
#DETERMINING IF THERE IS CORRELATION BETWEEN THE RESTAURANTS LOCATION AND ITS RATING.
cmtrix=data1[['Latitude','Longitude','Aggregate rating']].corr()
cmtrix
# Out:
#                   Latitude  Longitude  Aggregate rating
# Latitude          1.000000   0.045415          0.000197
# Longitude         0.045415   1.000000         -0.114733
# Aggregate rating  0.000197  -0.114733          1.000000

# %% [markdown]
# --......................................................................................................................................................................................................................................................................--

# %%
path="C:/Users/Lezan/Downloads/newdata1.csv"
data1.to_csv(path,index=False)
